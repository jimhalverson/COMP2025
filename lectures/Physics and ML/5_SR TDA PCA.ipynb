# %% [markdown]
# # Symbolic Regression
#
# In this lecture we study symbolic regression, which is a method for finding a symbolic expression that fits a given data set.

# %% [markdown]
# ### $ F \propto 1/r^2$

# %%
import os
os.environ['PYTHON_JULIACALL_HANDLE_SIGNALS'] = 'yes'
os.environ['JULIA_PYTHONCALL_EXE'] = '@PyCall'

# %%
import torchvision, torch, numpy 

torch.__version__, numpy.__version__, torchvision.__version__
# Out:
# ('2.7.0', '2.3.2', '0.22.0')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rs = np.linspace(.1, 1, 100)
Fs = 1/rs**2
rs = rs.reshape(rs.shape[0], 1)
# noise_with_Fs_dependent_variance = np.random.normal(0, 1/rs, Fs.shape)
noised_Fs = Fs + np.random.normal(0, .2*Fs, Fs.shape)
plt.scatter(rs, Fs, label='F', alpha=.5)
plt.scatter(rs, noised_Fs, label='noised_F', alpha=.5)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(rs, Fs, label='F', alpha=.5)
plt.scatter(rs, noised_Fs, label='noised_F', alpha=.5)

# %%
# !pip3 install -U pysr
# !python3 -m pysr install

# %%
from pysr import PySRRegressor

model = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=["+", "*"],
    unary_operators=[
        "cos",
        "exp",
        "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    verbosity=0,  # This reduces output and may help avoid the UTF-8 issue
    # ^ Custom loss function (julia syntax)
)
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:1036: FutureWarning: `loss` has been renamed to `elementwise_loss` in PySRRegressor. Please use that instead.
#   warnings.warn(

# %% [markdown]
# Let's try this first on Fs.

# %%
model.fit(rs, Fs)
model.get_best()
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# complexity                                                    9
# loss                                                        0.0
# equation                inv((x0 * 3.6159516e-8) + x0) * inv(x0)
# score                                                  0.249658
# sympy_format                      1/(x0*(x0*3.6159516e-8 + x0))
# lambda_format    PySRFunction(X=>1/(x0*(x0*3.6159516e-8 + x0)))
# Name: 5, dtype: object

# %% [markdown]
# Very clean. Exactly as expected.

# %%
model.fit(rs, noised_Fs)
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2217: UserWarning: The discovered expressions are being reset. Please set `warm_start=True` if you wish to continue to start a search where you left off.
#   warnings.warn(
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          10.585251
# 	1         0.004057                                            inv(x0)
# 	2         0.001417                                       inv(sin(x0))
# 	3         3.231650                                       inv(x0 * x0)
# 	4         0.001637                                  inv(x0 * sin(x0))
# 	5         0.097266                    inv((x0 * x0) + -0.00070652785)
# 	6         0.000849       inv((x0 + -0.0070212334) * x0) + -0.27081856
# 	7         0.001135  (inv(x0) + -0.121334516) * inv(x0 + -0.008211043)
# 	8         0.466042         (cos(x0 * -192.28917) + inv(x0)) * inv(x0)
# 	9         0.020397     inv(x0) * (cos(sin(x0) * -192.9756) + inv(x0))
# 	10        0.092524  inv(x0 + -0.0050579347) * (inv(x0) + cos(x0 * ...
# 	11        0.015157  ((inv(x0) + cos(sin(x0) * -193.82181)) * inv(x...
# 	12        0.029404  inv(-0.0050579635 + x0) * (inv(x0) + cos(sin(s...
# 	13        0.050603  inv(x0 + -0.0299422) * (cos((x0 + -0.6706515) ...
# 	14        0.025959  inv(x0 + -0.030210726) * (cos((sin(x0) + -0.66...
# 	15  >>>>  0.129011  ((inv(x0) + -1.8216194) * ((inv(x0) + (cos(x0 ...
# 	16        0.034003  (((inv(x0) + (cos((x0 * -186.05695) + -0.97855...
# 	17        0.023893  ((inv(x0) + (2.6621766 + (cos((x0 + -1.5545049...
# 	18        0.000572  ((x0 * x0) + (2.1096947 + ((inv(x0) + -1.83552...
# 	19        0.026175  ((inv(x0) + cos(inv((x0 + x0) + cos((x0 + (x0 ...
# 	20        0.001639  ((inv(x0) + cos(-1.1557833 + inv((x0 + x0) + c...
#
# 	          loss  complexity
# 	0   364.227080           1
# 	1   362.752530           2
# 	2   362.238950           3
# 	3    14.305650           4
# 	4    14.282256           5
# 	5    12.958497           6
# 	6    12.936524           8
# 	7    12.921853           9
# 	8     8.108215          10
# 	9     7.944504          11
# 	10    7.242427          12
# 	11    7.133483          13
# 	12    6.926784          14
# 	13    6.260060          16
# 	14    6.099649          17
# 	15    5.361372          18
# 	16    5.008892          20
# 	17    4.775167          22
# 	18    4.764260          26
# 	19    4.521265          28
# 	20    4.506473          30
# ]

# %%
model.get_best()
# Out:
# complexity                                                      18
# loss                                                      5.361372
# equation         ((inv(x0) + -1.8216194) * ((inv(x0) + (cos(x0 ...
# score                                                     0.129011
# sympy_format     (-1.8216194 + 1/x0)*(cos(x0*(-193.12636))*1.87...
# lambda_format    PySRFunction(X=>(-1.8216194 + 1/x0)*(cos(x0*(-...
# Name: 15, dtype: object

# %%
model.get_hof()
# Out:
#     complexity        loss                                           equation  \
# 0            1  364.227080                                          10.585251
# 1            2  362.752530                                            inv(x0)
# 2            3  362.238950                                       inv(sin(x0))
# 3            4   14.305650                                       inv(x0 * x0)
# 4            5   14.282256                                  inv(x0 * sin(x0))
# 5            6   12.958497                    inv((x0 * x0) + -0.00070652785)
# 6            8   12.936524       inv((x0 + -0.0070212334) * x0) + -0.27081856
# 7            9   12.921853  (inv(x0) + -0.121334516) * inv(x0 + -0.008211043)
# 8           10    8.108215         (cos(x0 * -192.28917) + inv(x0)) * inv(x0)
# 9           11    7.944504     inv(x0) * (cos(sin(x0) * -192.9756) + inv(x0))
# 10          12    7.242427  inv(x0 + -0.0050579347) * (inv(x0) + cos(x0 * ...
# 11          13    7.133483  ((inv(x0) + cos(sin(x0) * -193.82181)) * inv(x...
# 12          14    6.926784  inv(-0.0050579635 + x0) * (inv(x0) + cos(sin(s...
# 13          16    6.260060  inv(x0 + -0.0299422) * (cos((x0 + -0.6706515) ...
# 14          17    6.099649  inv(x0 + -0.030210726) * (cos((sin(x0) + -0.66...
# 15          18    5.361372  ((inv(x0) + -1.8216194) * ((inv(x0) + (cos(x0 ...
# 16          20    5.008892  (((inv(x0) + (cos((x0 * -186.05695) + -0.97855...
# 17          22    4.775167  ((inv(x0) + (2.6621766 + (cos((x0 + -1.5545049...
# 18          26    4.764260  ((x0 * x0) + (2.1096947 + ((inv(x0) + -1.83552...
# 19          28    4.521265  ((inv(x0) + cos(inv((x0 + x0) + cos((x0 + (x0 ...
# 20          30    4.506473  ((inv(x0) + cos(-1.1557833 + inv((x0 + x0) + c...
#
#        score                                       sympy_format  \
# 0   0.000000                                   10.5852510000000
# 1   0.004057                                               1/x0
# 2   0.001417                                          1/sin(x0)
# 3   3.231650                                           x0**(-2)
# 4   0.001637                                     1/(x0*sin(x0))
# 5   0.097266                          1/(x0*x0 - 0.00070652785)
# 6   0.000849           -0.27081856 + 1/(x0*(x0 - 0.0070212334))
# 7   0.001135           (-0.121334516 + 1/x0)/(x0 - 0.008211043)
# 8   0.466042                   (cos(x0*(-192.28917)) + 1/x0)/x0
# 9   0.020397               (cos(sin(x0)*(-192.9756)) + 1/x0)/x0
# 10  0.092524  (cos(x0*(-192.60735)) + 1/x0)/(x0 - 0.0050579347)
# 11  0.015157    (cos(sin(x0)*(-193.82181)) + 1/x0)*1.0425729/x0
# 12  0.029404  (cos(sin(sin(x0))*(-192.60735)) + 1/x0)/(x0 - ...
# 13  0.050603  (cos((x0 - 0.6706515)*(-185.70735)) + 1/(x0 + ...
# 14  0.025959  (cos((sin(x0) - 0.66988635)*(-185.70735)) + 1/...
# 15  0.129011  (-1.8216194 + 1/x0)*(cos(x0*(-193.12636))*1.87...
# 16  0.034003  (-1.7519422 + 1/x0)*(cos(x0*(-186.05695) - 0.9...
# 17  0.023893  x0*4.007171 + (-1.7181011 + 1/x0)*(cos((x0 - 1...
# 18  0.000572  x0*x0 + x0 + (-1.835528 + 1/x0)*(cos(x0*(-186....
# 19  0.026175  x0 + (-1.0760368 + 1.1738124/x0)*(cos(-1.12923...
# 20  0.001639  x0 + (-1.0760368 + 1.1738124/x0)*(cos(-1.15578...
#
#                                         lambda_format
# 0                   PySRFunction(X=>10.5852510000000)
# 1                               PySRFunction(X=>1/x0)
# 2                          PySRFunction(X=>1/sin(x0))
# 3                           PySRFunction(X=>x0**(-2))
# 4                     PySRFunction(X=>1/(x0*sin(x0)))
# 5          PySRFunction(X=>1/(x0*x0 - 0.00070652785))
# 6   PySRFunction(X=>-0.27081856 + 1/(x0*(x0 - 0.00...
# 7   PySRFunction(X=>(-0.121334516 + 1/x0)/(x0 - 0....
# 8   PySRFunction(X=>(cos(x0*(-192.28917)) + 1/x0)/x0)
# 9   PySRFunction(X=>(cos(sin(x0)*(-192.9756)) + 1/...
# 10  PySRFunction(X=>(cos(x0*(-192.60735)) + 1/x0)/...
# 11  PySRFunction(X=>(cos(sin(x0)*(-193.82181)) + 1...
# 12  PySRFunction(X=>(cos(sin(sin(x0))*(-192.60735)...
# 13  PySRFunction(X=>(cos((x0 - 0.6706515)*(-185.70...
# 14  PySRFunction(X=>(cos((sin(x0) - 0.66988635)*(-...
# 15  PySRFunction(X=>(-1.8216194 + 1/x0)*(cos(x0*(-...
# 16  PySRFunction(X=>(-1.7519422 + 1/x0)*(cos(x0*(-...
# 17  PySRFunction(X=>x0*4.007171 + (-1.7181011 + 1/...
# 18  PySRFunction(X=>x0*x0 + x0 + (-1.835528 + 1/x0...
# 19  PySRFunction(X=>x0 + (-1.0760368 + 1.1738124/x...
# 20  PySRFunction(X=>x0 + (-1.0760368 + 1.1738124/x...

# %% [markdown]
# OK, so it may or may not have worked again, depending on the seed. But presumably if we added TOO much noise, it would fail eventually.

# %%
noised_Fs = Fs + np.random.normal(0, .3*Fs, Fs.shape)
plt.scatter(rs, noised_Fs)
plt.xscale('log')
plt.yscale('log')

model.fit(rs, noised_Fs)
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2217: UserWarning: The discovered expressions are being reset. Please set `warm_start=True` if you wish to continue to start a search where you left off.
#   warnings.warn(
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          10.726567
# 	1         0.625265                                       inv(x0 * x0)
# 	2         0.001241                                  inv(x0 * sin(x0))
# 	3         0.132109               exp((x0 + -0.51678413) * -10.829477)
# 	4         0.002722          exp((sin(x0) + -0.51678413) * -10.829477)
# 	5         0.055419       exp((x0 * -11.58442) + 5.628698) + 1.9803207
# 	6         0.027591       (sin(inv(sin(inv(x0)))) + inv(x0)) * inv(x0)
# 	7         0.037929  inv(x0) * (sin(inv(sin(inv(sin(x0))))) + inv(x0))
# 	8         0.091762  inv(x0) * (inv(x0) + sin(inv(sin(inv(x0) + 1.1...
# 	9         0.020495  (inv(x0) + sin(inv(sin(sin(inv(x0) + 0.3291384...
# 	10        0.003781  (inv(x0) + sin(inv(sin(sin(sin(0.20119658) + i...
# 	11        0.064015  (inv(x0) + (sin(inv(sin(sin(1.1670352 + inv(x0...
# 	12        0.060160  ((inv(x0) + -2.6896923) * (exp(sin(inv(sin(inv...
# 	13        0.089282  ((inv(x0) + -2.9289007) * (exp(sin(inv(sin(inv...
# 	14        0.088570  ((inv(x0) + -2.9289007) * (exp(sin(inv(sin(inv...
# 	15        0.016042  (((inv(x0) + exp(sin(inv(sin(inv(sin(x0))))) +...
# 	16        0.067558  ((inv(x0) + exp(sin(inv(cos(inv(x0) + -12.9378...
# 	17  >>>>  0.113162  (((inv(x0) + exp(sin(inv(sin(sin(inv(sin(sin(x...
# 	18        0.068097  (((inv(x0) + -2.2077668) * (exp(sin(sin(inv(si...
# 	19        0.004351  (((inv(x0) + -2.2077668) * (inv(sin(x0)) + exp...
#
# 	          loss  complexity
# 	0   373.514650           1
# 	1    57.234863           4
# 	2    57.163887           5
# 	3    50.089590           6
# 	4    49.953407           7
# 	5    47.260345           8
# 	6    43.505993          11
# 	7    41.886753          12
# 	8    38.214214          13
# 	9    37.438988          14
# 	10   37.297680          15
# 	11   34.984875          16
# 	12   31.018858          18
# 	13   28.369463          19
# 	14   25.964853          20
# 	15   25.551638          21
# 	16   23.882446          22
# 	17   17.007545          25
# 	18   15.887934          26
# 	19   15.818961          27
# ]

# %%
# plot model hall of fame

model.get_hof()
# Out:
#     complexity        loss                                           equation  \
# 0            1  373.514650                                          10.726567
# 1            4   57.234863                                       inv(x0 * x0)
# 2            5   57.163887                                  inv(x0 * sin(x0))
# 3            6   50.089590               exp((x0 + -0.51678413) * -10.829477)
# 4            7   49.953407          exp((sin(x0) + -0.51678413) * -10.829477)
# 5            8   47.260345       exp((x0 * -11.58442) + 5.628698) + 1.9803207
# 6           11   43.505993       (sin(inv(sin(inv(x0)))) + inv(x0)) * inv(x0)
# 7           12   41.886753  inv(x0) * (sin(inv(sin(inv(sin(x0))))) + inv(x0))
# 8           13   38.214214  inv(x0) * (inv(x0) + sin(inv(sin(inv(x0) + 1.1...
# 9           14   37.438988  (inv(x0) + sin(inv(sin(sin(inv(x0) + 0.3291384...
# 10          15   37.297680  (inv(x0) + sin(inv(sin(sin(sin(0.20119658) + i...
# 11          16   34.984875  (inv(x0) + (sin(inv(sin(sin(1.1670352 + inv(x0...
# 12          18   31.018858  ((inv(x0) + -2.6896923) * (exp(sin(inv(sin(inv...
# 13          19   28.369463  ((inv(x0) + -2.9289007) * (exp(sin(inv(sin(inv...
# 14          20   25.964853  ((inv(x0) + -2.9289007) * (exp(sin(inv(sin(inv...
# 15          21   25.551638  (((inv(x0) + exp(sin(inv(sin(inv(sin(x0))))) +...
# 16          22   23.882446  ((inv(x0) + exp(sin(inv(cos(inv(x0) + -12.9378...
# 17          25   17.007545  (((inv(x0) + exp(sin(inv(sin(sin(inv(sin(sin(x...
# 18          26   15.887934  (((inv(x0) + -2.2077668) * (exp(sin(sin(inv(si...
# 19          27   15.818961  (((inv(x0) + -2.2077668) * (inv(sin(x0)) + exp...
#
#        score                                       sympy_format  \
# 0   0.000000                                   10.7265670000000
# 1   0.625265                                           x0**(-2)
# 2   0.001241                                     1/(x0*sin(x0))
# 3   0.132109                exp((x0 - 0.51678413)*(-10.829477))
# 4   0.002722           exp((sin(x0) - 0.51678413)*(-10.829477))
# 5   0.055419         exp(5.628698 + x0*(-11.58442)) + 1.9803207
# 6   0.027591                       (sin(1/sin(1/x0)) + 1/x0)/x0
# 7   0.037929                  (sin(1/sin(1/sin(x0))) + 1/x0)/x0
# 8   0.091762           (sin(1/sin(1.1670352 + 1/x0)) + 1/x0)/x0
# 9   0.020495     (sin(1/sin(sin(0.32913846 + 1/x0))) + 1/x0)/x0
# 10  0.003781  (sin(1/sin(sin(sin(0.20119658) + 1/x0))) + 1/x...
# 11  0.064015  (sin(1/sin(sin(1.1670352 + 1/x0)))*1.286797 + ...
# 12  0.060160  (-2.6896923 + 1/x0)*(exp(sin(1/sin(1/x0)) + 0....
# 13  0.089282  (-2.9289007 + 1/x0)*(exp(sin(1/sin(1/x0)) + co...
# 14  0.088570  (-2.9289007 + 1/x0)*(exp(sin(1/sin(1/sin(x0)))...
# 15  0.016042  ((-2.3420386 + 1/x0)*(exp(sin(1/sin(1/sin(x0))...
# 16  0.067558  (-1.6342416 + 1/x0)*(exp(sin(1/x0) + sin(1/cos...
# 17  0.113162  ((-2.207767 + 1/x0)*(exp(sin(1/(sin(sin(1/sin(...
# 18  0.068097  ((-2.2077668 + 1/x0)*(exp(sin(sin(1/(sin(sin(1...
# 19  0.004351  ((-2.2077668 + 1/x0)*(exp(sin(sin(1/(sin(sin(1...
#
#                                         lambda_format
# 0                   PySRFunction(X=>10.7265670000000)
# 1                           PySRFunction(X=>x0**(-2))
# 2                     PySRFunction(X=>1/(x0*sin(x0)))
# 3   PySRFunction(X=>exp((x0 - 0.51678413)*(-10.829...
# 4   PySRFunction(X=>exp((sin(x0) - 0.51678413)*(-1...
# 5   PySRFunction(X=>exp(5.628698 + x0*(-11.58442))...
# 6       PySRFunction(X=>(sin(1/sin(1/x0)) + 1/x0)/x0)
# 7   PySRFunction(X=>(sin(1/sin(1/sin(x0))) + 1/x0)...
# 8   PySRFunction(X=>(sin(1/sin(1.1670352 + 1/x0)) ...
# 9   PySRFunction(X=>(sin(1/sin(sin(0.32913846 + 1/...
# 10  PySRFunction(X=>(sin(1/sin(sin(sin(0.20119658)...
# 11  PySRFunction(X=>(sin(1/sin(sin(1.1670352 + 1/x...
# 12  PySRFunction(X=>(-2.6896923 + 1/x0)*(exp(sin(1...
# 13  PySRFunction(X=>(-2.9289007 + 1/x0)*(exp(sin(1...
# 14  PySRFunction(X=>(-2.9289007 + 1/x0)*(exp(sin(1...
# 15  PySRFunction(X=>((-2.3420386 + 1/x0)*(exp(sin(...
# 16  PySRFunction(X=>(-1.6342416 + 1/x0)*(exp(sin(1...
# 17  PySRFunction(X=>((-2.207767 + 1/x0)*(exp(sin(1...
# 18  PySRFunction(X=>((-2.2077668 + 1/x0)*(exp(sin(...
# 19  PySRFunction(X=>((-2.2077668 + 1/x0)*(exp(sin(...

# %% [markdown]
# Notice the stratification in the loss. It starts very high, but then gets much lower by the time we get to 1/x^2. This shows we're not getting a lot more beyond the 1/x^2, so balancing complexity and loss, this is the best model.

# %% [markdown]
# ### Damped Harmonic Oscillator

# %%
import numpy as np
num_samples = 100
time_end = 5
times = np.linspace(0, time_end, num_samples)
x_data = np.array([ 1.42136407e+00,  1.32538052e+00,  1.08997205e+00,  4.01375320e-01,
       -1.78495795e-01, -8.50696683e-01, -1.18615104e+00, -1.42918430e+00,
       -1.08653056e+00, -5.51030603e-01, -7.50736710e-02,  6.47062767e-01,
        1.01484947e+00,  1.23909135e+00,  1.16973363e+00,  7.14521669e-01,
        3.55287429e-01, -2.95169206e-01, -9.74425168e-01, -1.16492314e+00,
       -9.52631079e-01, -7.77656938e-01, -3.28057458e-01,  2.92744065e-01,
        6.01953380e-01,  8.65371671e-01,  9.54240091e-01,  7.08483475e-01,
        4.68455172e-01, -1.56245101e-01, -3.70602686e-01, -8.30733462e-01,
       -8.95167164e-01, -8.91137955e-01, -4.18014142e-01, -2.22376053e-01,
        4.10047775e-01,  6.88406843e-01,  1.04061990e+00,  7.30025281e-01,
        3.90618018e-01,  1.43181366e-01, -2.20778546e-01, -4.53298514e-01,
       -7.87562022e-01, -7.21285197e-01, -6.27664217e-01, -4.65873073e-01,
        4.76786963e-02,  3.89328316e-01,  5.92877625e-01,  6.37519856e-01,
        4.83785342e-01,  1.71821980e-01,  5.43082539e-02, -3.29509591e-01,
       -4.12974420e-01, -5.53475010e-01, -5.83206553e-01, -4.58252882e-01,
       -5.48980467e-02,  2.26195369e-01,  4.52451610e-01,  5.38430311e-01,
        3.67845822e-01,  3.97176254e-01,  1.84432283e-01, -1.49708735e-01,
       -5.37683940e-01, -3.88877197e-01, -6.79843289e-01, -4.05592818e-01,
       -2.06048677e-01, -3.04612159e-02,  2.73534969e-01,  2.33194682e-01,
        4.87619039e-01,  3.34767833e-01,  3.00019677e-01,  9.12268252e-03,
       -1.21252257e-01, -2.57336778e-01, -4.68953016e-01, -5.12673830e-01,
       -2.89839003e-02, -3.22855227e-01,  5.86021068e-02,  8.32512072e-02,
        2.60554538e-01,  3.23171785e-01,  4.29277758e-01,  8.75180664e-02,
       -1.17562189e-03, -5.57391100e-02, -2.43060644e-01, -3.07899430e-01,
       -1.78936431e-01, -2.53676100e-01, -9.54204646e-02,  2.55114941e-01])
x_data = x_data.reshape(x_data.shape[0], 1)
times = times.reshape(times.shape[0], 1)

# %%
from pysr import PySRRegressor

model = PySRRegressor(
    niterations=500,  # < Increase me for better results
    binary_operators=["+", "*"],
    unary_operators=[
        "cos",
        "exp",
        "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    verbosity=0
    # ^ Custom loss function (julia syntax)
)
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:1036: FutureWarning: `loss` has been renamed to `elementwise_loss` in PySRRegressor. Please use that instead.
#   warnings.warn(

# %%
model.fit(times, x_data)
# Out:
# /opt/anaconda3/envs/kan/lib/python3.13/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                        -0.00198704
# 	1         0.000651                                  x0 * -0.007516606
# 	2         1.215067                                cos(x0 * -9.781544)
# 	3         0.218382                           sin(cos(x0 * 9.7802305))
# 	4         0.112562                   cos(x0 * -9.779522) * 0.75425094
# 	5         0.000638              sin(sin((x0 + 2.6759079) * 9.874695))
# 	6         0.111297     sin((x0 + 0.76682353) * 9.875645) * 0.76413184
# 	7         0.841407         cos(x0 * -9.759643) * cos(x0 * 0.28452548)
# 	8         0.402523  cos(x0 * -9.755005) * ((x0 * -0.23382014) + 1....
# 	9         0.070983  (cos(x0 * -9.757031) * exp(x0 * -0.3170593)) *...
# 	10  >>>>  0.635510  sin((x0 + 2.6754918) * 9.87697) * ((x0 * -0.23...
# 	11        0.157879  sin((x0 + 2.67712) * 9.873104) * exp((x0 * -0....
# 	12        0.015108  sin((x0 + 2.6767166) * 9.873973) * (sin(exp(x0...
# 	13        0.005382  (exp((x0 * -0.31641203) + 0.40421718) * sin((x...
# 	14        0.014237  (sin(exp(x0 * -0.35724637)) * (sin((x0 + 2.676...
# 	15        0.003402  ((x0 * -0.0100426795) + sin((x0 + 2.676585) * ...
# 	16        0.008183  ((sin(9.871733 * (x0 + 2.6778162)) * sin(exp(x...
# 	17        0.043184  (0.038678046 * sin(x0 * -21.96302)) + (exp((-0...
# 	18        0.001348  (sin(sin(x0 * -21.98165)) * 0.044820495) + (si...
# 	19        0.023586  (sin((x0 * x0) * 23.641424) * -0.047826365) + ...
# 	20        0.046271  exp((((sin(0.32162717 * exp(x0 + x0)) * 0.0453...
# 	21        0.006375  (sin((x0 * 9.873431) + 1.2886996) * exp((((sin...
# 	22        0.000178  -0.012030315 + (sin(1.2886996 + (9.873431 * x0...
# 	23        0.000276  -0.012030315 + (sin(1.2886996 + (9.873431 * x0...
# 	24        0.040530  sin((x0 * 9.870717) + 1.2970623) * exp((((sin(...
#
# 	        loss  complexity
# 	0   0.360228           1
# 	1   0.359759           3
# 	2   0.106737           4
# 	3   0.085797           5
# 	4   0.076663           6
# 	5   0.076615           7
# 	6   0.068545           8
# 	7   0.029550           9
# 	8   0.019758          10
# 	9   0.018404          11
# 	10  0.009748          12
# 	11  0.008324          13
# 	12  0.008200          14
# 	13  0.008156          15
# 	14  0.008040          16
# 	15  0.007986          18
# 	16  0.007921          19
# 	17  0.007586          20
# 	18  0.007576          21
# 	19  0.007399          22
# 	20  0.007065          23
# 	21  0.006975          25
# 	22  0.006974          26
# 	23  0.006972          27
# 	24  0.006695          28
# ]

# %%
print(model.get_best())
model.get_hof()
# Out:
# complexity                                                      12
# loss                                                      0.009748
# equation         sin((x0 + 2.6754918) * 9.87697) * ((x0 * -0.23...
# score                                                      0.63551
# sympy_format     (1.3419908 + x0*(-0.23573427))*sin((x0 + 2.675...
# lambda_format    PySRFunction(X=>(1.3419908 + x0*(-0.23573427))...
# Name: 10, dtype: object
#     complexity      loss                                           equation  \
# 0            1  0.360228                                        -0.00198704
# 1            3  0.359759                                  x0 * -0.007516606
# 2            4  0.106737                                cos(x0 * -9.781544)
# 3            5  0.085797                           sin(cos(x0 * 9.7802305))
# 4            6  0.076663                   cos(x0 * -9.779522) * 0.75425094
# 5            7  0.076615              sin(sin((x0 + 2.6759079) * 9.874695))
# 6            8  0.068545     sin((x0 + 0.76682353) * 9.875645) * 0.76413184
# 7            9  0.029550         cos(x0 * -9.759643) * cos(x0 * 0.28452548)
# 8           10  0.019758  cos(x0 * -9.755005) * ((x0 * -0.23382014) + 1....
# 9           11  0.018404  (cos(x0 * -9.757031) * exp(x0 * -0.3170593)) *...
# 10          12  0.009748  sin((x0 + 2.6754918) * 9.87697) * ((x0 * -0.23...
# 11          13  0.008324  sin((x0 + 2.67712) * 9.873104) * exp((x0 * -0....
# 12          14  0.008200  sin((x0 + 2.6767166) * 9.873973) * (sin(exp(x0...
# 13          15  0.008156  (exp((x0 * -0.31641203) + 0.40421718) * sin((x...
# 14          16  0.008040  (sin(exp(x0 * -0.35724637)) * (sin((x0 + 2.676...
# 15          18  0.007986  ((x0 * -0.0100426795) + sin((x0 + 2.676585) * ...
# 16          19  0.007921  ((sin(9.871733 * (x0 + 2.6778162)) * sin(exp(x...
# 17          20  0.007586  (0.038678046 * sin(x0 * -21.96302)) + (exp((-0...
# 18          21  0.007576  (sin(sin(x0 * -21.98165)) * 0.044820495) + (si...
# 19          22  0.007399  (sin((x0 * x0) * 23.641424) * -0.047826365) + ...
# 20          23  0.007065  exp((((sin(0.32162717 * exp(x0 + x0)) * 0.0453...
# 21          25  0.006975  (sin((x0 * 9.873431) + 1.2886996) * exp((((sin...
# 22          26  0.006974  -0.012030315 + (sin(1.2886996 + (9.873431 * x0...
# 23          27  0.006972  -0.012030315 + (sin(1.2886996 + (9.873431 * x0...
# 24          28  0.006695  sin((x0 * 9.870717) + 1.2970623) * exp((((sin(...
#
#        score                                       sympy_format  \
# 0   0.000000                               -0.00198704000000000
# 1   0.000651                                  x0*(-0.007516606)
# 2   1.215067                                cos(x0*(-9.781544))
# 3   0.218382                             sin(cos(x0*9.7802305))
# 4   0.112562                     cos(x0*(-9.779522))*0.75425094
# 5   0.000638                sin(sin((x0 + 2.6759079)*9.874695))
# 6   0.111297         sin((x0 + 0.76682353)*9.875645)*0.76413184
# 7   0.841407             cos(x0*(-9.759643))*cos(x0*0.28452548)
# 8   0.402523  (1.3299398 + x0*(-0.23382014))*cos(x0*(-9.7550...
# 9   0.070983  cos(x0*(-9.757031))*exp(x0*(-0.3170593))*1.486382
# 10  0.635510  (1.3419908 + x0*(-0.23573427))*sin((x0 + 2.675...
# 11  0.157879  exp(0.40248582 + x0*(-0.31530708))*sin((x0 + 2...
# 12  0.015108  sin((x0 + 2.6767166)*9.873973)*sin(exp(x0*(-0....
# 13  0.005382  exp(0.40421718 + x0*(-0.31641203))*sin((x0 + 2...
# 14  0.014237  sin(exp(x0*(-0.35724637)))*sin((x0 + 2.6760678...
# 15  0.003402  (x0*(-0.0100426795) + sin((x0 + 2.676585)*9.87...
# 16  0.008183  sin(9.871733*(x0 + 2.6778162))*sin(exp(x0*(-0....
# 17  0.043184  exp(0.405761 - 0.31643045*x0)*sin(9.873631*(x0...
# 18  0.001348  exp(0.406014 + x0*(-0.31679907))*sin((x0 + 0.1...
# 19  0.023586  exp(0.40532213 + x0*(-0.31862226))*sin((x0 + 2...
# 20  0.046271  exp(x0*(sin(0.32162717*exp(x0 + x0))*0.0453617...
# 21  0.006375  exp(x0*(sin(exp(x0 + x0)*0.32162717)*0.0453617...
# 22  0.000178  exp(x0*sin(0.045361795*sin(0.32162717*exp(x0 +...
# 23  0.000276  exp(x0*sin(0.045361795*sin(0.32162717*exp(x0 +...
# 24  0.040530  exp(x0*(sin(x0*exp(x0)*(-1.2096684)*(sin(x0) +...
#
#                                         lambda_format
# 0               PySRFunction(X=>-0.00198704000000000)
# 1                  PySRFunction(X=>x0*(-0.007516606))
# 2                PySRFunction(X=>cos(x0*(-9.781544)))
# 3             PySRFunction(X=>sin(cos(x0*9.7802305)))
# 4     PySRFunction(X=>cos(x0*(-9.779522))*0.75425094)
# 5   PySRFunction(X=>sin(sin((x0 + 2.6759079)*9.874...
# 6   PySRFunction(X=>sin((x0 + 0.76682353)*9.875645...
# 7   PySRFunction(X=>cos(x0*(-9.759643))*cos(x0*0.2...
# 8   PySRFunction(X=>(1.3299398 + x0*(-0.23382014))...
# 9   PySRFunction(X=>cos(x0*(-9.757031))*exp(x0*(-0...
# 10  PySRFunction(X=>(1.3419908 + x0*(-0.23573427))...
# 11  PySRFunction(X=>exp(0.40248582 + x0*(-0.315307...
# 12  PySRFunction(X=>sin((x0 + 2.6767166)*9.873973)...
# 13  PySRFunction(X=>exp(0.40421718 + x0*(-0.316412...
# 14  PySRFunction(X=>sin(exp(x0*(-0.35724637)))*sin...
# 15  PySRFunction(X=>(x0*(-0.0100426795) + sin((x0 ...
# 16  PySRFunction(X=>sin(9.871733*(x0 + 2.6778162))...
# 17  PySRFunction(X=>exp(0.405761 - 0.31643045*x0)*...
# 18  PySRFunction(X=>exp(0.406014 + x0*(-0.31679907...
# 19  PySRFunction(X=>exp(0.40532213 + x0*(-0.318622...
# 20  PySRFunction(X=>exp(x0*(sin(0.32162717*exp(x0 ...
# 21  PySRFunction(X=>exp(x0*(sin(exp(x0 + x0)*0.321...
# 22  PySRFunction(X=>exp(x0*sin(0.045361795*sin(0.3...
# 23  PySRFunction(X=>exp(x0*sin(0.045361795*sin(0.3...
# 24  PySRFunction(X=>exp(x0*(sin(x0*exp(x0)*(-1.209...

# %%
best = model.get_best()

# %%
best.equation
# Out:
# 'sin((x0 + 2.6754918) * 9.87697) * ((x0 * -0.23573427) + 1.3419908)'

# %% [markdown]
# A * np.exp(-beta * times) * np.cos(omega * times - delta)
#
# A_true = 1.4
#
# beta_true = 0.3
#
# omega_true = np.pi**2
#
# delta_true = 0.3

# %%
np.pi**2
# Out:
# 9.869604401089358

# %% [markdown]
# # Topological Data Analysis

# %% [markdown]
# Now we study topological data analysis. The essential question is, if your experiments or simulations sampled a manifold with non-trivial topology, how would you know it from a finite number of samples?
#
# In the figure below at small values of r, we simply see a collection of points. But they're clearly arranged in a way that makes it looks like they're sampled from either a collection of circles, or a cylinder -- it's not simply a connection of point. As we increase $r$, which in this video is simply the marker size, eventually everything overlaps and it's one big blob. Intuitively, that is also not the lesson that we're supposed to take away from the data.

# %%
from IPython.display import Image
Image(url='videos/PH.gif')
# Out:
# <img src="videos/PH.gif"/>

# %% [markdown]
# Roughly, a non-trivial $k$-cycle in a space is a $k$-dimensional subspace without boundary that is not the boundary of a $(k+1)$-dimensional subspace. For example, a torus has two one-cycles, which are the two circles that go around the torus. A two-sphere has no one-cycles, but it has a two-cycle, which is the entire sphere. Given a topological space, the dimensionality of the $k$-cycles is given by the so-called Betti numbers.
#
# The basic idea in persistent homology is to study how the Betti numbers change as a function of a so-called filtration parameter, $r$.
#
# In slightly more detail, to any value of $r$ we may associate a so-called Vietoris-Rips simplicial complex. Recall that a $k$-simplex is a $k$-dimensional subspace. A simplicial complex is a collection of simplices that is closed under taking subspaces. The Vietoris-Rips complex is the simplicial complex that is generated by the points in the data set, where we include a $k$-simplex if all of its vertices are within distance $r$ of each other. We see that it is clearly closed under taking subspaces because if we have a $k$-simplex, then all of its vertices are within distance $r$ of each other, and so are all of the vertices of any subspace of the $k$-simplex.
#
# We will be using the `ripser` package. The basic idea is that we can study the topology of a data set by looking at the persistence of the homology of the Vietoris-Rips complex of the data set.

# %%
num_samples = 500

def sample_from_annulus(num_samples, lower_radius = .5, upper_radius = 1):
    samples_from_unit_disk = np.random.uniform(-upper_radius, upper_radius, (1000*num_samples, 2))
    samples_from_unit_disk = samples_from_unit_disk[np.linalg.norm(samples_from_unit_disk, axis=1) < upper_radius]
    samples_from_annulus = samples_from_unit_disk[np.linalg.norm(samples_from_unit_disk, axis=1) > lower_radius]
    samples_from_annulus = samples_from_annulus[:num_samples]
    assert len(samples_from_annulus) == num_samples
    return samples_from_annulus
    
samps = sample_from_annulus(num_samples)

plt.scatter(samps[:, 0], samps[:, 1])

# %%
# three plots of annulus samples with 50, 100, 500 points, respectively
# put them in a row

plt.subplot(1, 3, 1)
samps = sample_from_annulus(50)
plt.ylim(-1,1)
plt.scatter(samps[:, 0], samps[:, 1])
plt.title('50 samples')
plt.axis('equal')
plt.subplot(1, 3, 2)
samps = sample_from_annulus(100)
plt.ylim(-1,1)
plt.scatter(samps[:, 0], samps[:, 1])
plt.title('100 samples')
plt.axis('equal')
plt.subplot(1, 3, 3)
samps = sample_from_annulus(500)
plt.ylim(-1,1)
plt.scatter(samps[:, 0], samps[:, 1])
plt.title('500 samples')
plt.axis('equal')

# set aspect ratios equal
# Out:
# (np.float64(-1.0910105587447816),
#  np.float64(1.078180786896837),
#  np.float64(-1.092872002143245),
#  np.float64(1.0825524857534654))

# %%
# !pip install ripser
# !pip install persim
# Out:
# Requirement already satisfied: ripser in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (0.6.12)
# Requirement already satisfied: Cython in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from ripser) (3.2.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from ripser) (2.3.2)
# Requirement already satisfied: persim in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from ripser) (0.3.8)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from ripser) (1.16.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from ripser) (1.7.2)
# Requirement already satisfied: deprecated in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim->ripser) (1.3.1)
# Requirement already satisfied: hopcroftkarp in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim->ripser) (1.2.5)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim->ripser) (1.5.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim->ripser) (3.10.3)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from deprecated->persim->ripser) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim->ripser) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->persim->ripser) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from scikit-learn->ripser) (3.6.0)
# Requirement already satisfied: persim in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (0.3.8)
# Requirement already satisfied: deprecated in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (1.3.1)
# Requirement already satisfied: hopcroftkarp in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (1.2.5)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (1.5.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (3.10.3)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (2.3.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from persim) (1.7.2)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from deprecated->persim) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from matplotlib->persim) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->persim) (1.17.0)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from scikit-learn->persim) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/kan/lib/python3.13/site-packages (from scikit-learn->persim) (3.6.0)

# %%
from ripser import ripser
from persim import plot_diagrams

data = ripser(samps)
diagrams = data['dgms']

# %%
plt.figure(figsize=(8, 4))
plot_diagrams(diagrams, show=True)

# %%
for lower_radius in [0.2, 0.4, 0.6, 0.8]:
    samps = sample_from_annulus(num_samples, lower_radius=lower_radius)
    plt.scatter(samps[:, 0], samps[:, 1])
    plt.show()

    data = ripser(samps)
    diagrams = data['dgms']
    plt.figure(figsize=(8, 4))
    plot_diagrams(diagrams, show=True)

# %% [markdown]
# For a fixed number of samples, having a smaller lower_radius makes the samples look like a blob. Accordingly, in the TDA you can't see a meaningful one-cycle. But as the lower_radius increases, the one-cycle becomes more and more visible, as evidenced by the $H_1$ gap in the persistence diagram.

# %% [markdown]
# # PCA: Principal Component Analysis
#
# In this lecture we study PCA, which is a method for finding a low-dimensional subspace that captures the most variance in a data set. The principal components are eigenvectors of the covariance matrix. The idea is that the different principle components explain the variance in the data.
#
# But how much of the variance is explained by each component? If the $i^\text{th}$ principal component is the $i^{th}$ eigenvector of the covariance matrix, then the size of its eigenvalue (relative to the sum of all of them) tells you "how much" of the variance is explained by that component.
#
# In equations
#
# $$
# \text{variance explained by $i^\text{th}$ component} = \frac{\lambda_i}{\sum_j \lambda_j}
# $$
#
# where $\lambda_i$ is the $i^\text{th}$ eigenvalue of the covariance matrix.
#
# This normalized sum is called the explained variance ratio.

# %%
import numpy as np

angle = np.pi/4
R = np.array([[np.cos(angle), -np.sin(angle)], [np.sin(angle), np.cos(angle)]])
diag_cov  = np.array([[10,0],[0,1]])
cov = R @ diag_cov @ R.T

Xs = np.random.multivariate_normal([0, 0], cov, 1000)
plt.scatter(Xs[:, 0], Xs[:, 1])

# %% [markdown]
# We have successfully created a dataset that is rotated and has a clear principal component. Let's see if we can find it by computing PCA by hand.

# %%
mean = np.mean(Xs, axis=0) # mean across data
centered_Xs = Xs - mean # fluctuations around mean
covariance = centered_Xs.T @ centered_Xs / len(Xs) # covariance matrix
print(centered_Xs.T.shape, centered_Xs.shape, covariance.shape)
# Out:
# (2, 1000) (1000, 2) (2, 2)

# %% [markdown]
# The princpal components are the eigenvectors of the covariance matrix. Let's study them.

# %%
evals, evecs = np.linalg.eig(covariance)
print(evals[0], evecs[:, 0])
print(evals[1], evecs[:, 1])
# Out:
# 10.6591269976076 [0.71521548 0.69890401]
# 1.0048431996848468 [-0.69890401  0.71521548]

# %%
explained_variances = evals / np.sum(evals)
print(explained_variances)
# Out:
# [0.91385067 0.08614933]

# %% [markdown]
# This matches expectations because we see the (-1,-1) direction gets weight 10 and the (-1,1) direction gets weight 1. So the principal component is the (-1,-1) direction. The precisely matches what we would have expected from `R` and `diag_cov` above.
#
# Let's make sure a pre-packaged library will give us the same thing.

# %%
# pca from sklearn
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(Xs)
print(pca.components_)
print(pca.explained_variance_ratio_)
# Out:
# [[ 0.71521548  0.69890401]
#  [-0.69890401  0.71521548]]
# [0.91385067 0.08614933]

# %% [markdown]
# We see that the explained variance and the principal components match what we computed by hand. Yes!
